# %% [markdown]
# #受難日第一天 20190923
#
# #程式超簡單

# %%
print("Hello Mydearselfishnigga!")
# Out:
# Hello Mydearselfishnigga!

# %%
print ("      *        ");
print ("     ***       ");
print ("    *****      ");
print ("      *        ");
# Out:
#       *
#      ***
#     *****
#       *

# %%
a=input("input:")
b=a+1
print(b)
# Out:
# input:100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-78eb159b7e40> in <module>()
#       1 a=input("input:")
# ----> 2 b=a+1
#       3 print(b)
#
# TypeError: must be str, not int

# %%
a=int(input("input:"))
b=a+1
print(b)
# Out:
# input:10
# 11
